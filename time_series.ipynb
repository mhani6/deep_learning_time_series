# %%
# !pip install -q tslearn scikit-learn torch
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.9/387.9 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 91.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.64.0 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.64.0 which is incompatible.

# %%
# !python train.py --model all --epochs 50 --batch_size 64
# Out:
# Device: cuda
# Loading LSST dataset...
#   Train: (2459, 36, 6)  |  Test: (2466, 36, 6)
#   Classes: ['15' '16' '42' '52' '53' '6' '62' '64' '65' '67' '88' '90' '92' '95']
#   Timesteps: 36  |  Channels: 6
# seq_len=36, n_channels=6, n_classes=14
#
# ...
# Training PatchTST
# ...
# /content/deep_learning_time_series/models/patchtst.py:99: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=n_layers)
# PatchTST — 156,366 trainable parameters
# Epoch 001/50 | Train loss 2.1687 acc 0.3367 | Val loss 2.0436 acc 0.3747 | Best acc 0.3747 | 2s
# Epoch 005/50 | Train loss 1.8086 acc 0.4551 | Val loss 1.7981 acc 0.4688 | Best acc 0.4688 | 4s
# Epoch 010/50 | Train loss 1.7263 acc 0.4974 | Val loss 1.7216 acc 0.5057 | Best acc 0.5114 | 8s
# Epoch 015/50 | Train loss 1.6645 acc 0.5181 | Val loss 1.6624 acc 0.5260 | Best acc 0.5260 | 11s
# ...

# %%
import json, glob
for f in glob.glob('runs/*_results.json'):
    with open(f) as fp:
        r = json.load(fp)
    print(f"{r['model']:12s} | acc={r['accuracy']:.4f} | f1={r['macro_f1']:.4f}")
# Out:
# baseline     | acc=0.5783 | f1=0.4324
# units        | acc=0.6606 | f1=0.5314
# patchtst     | acc=0.5985 | f1=0.4599

# %%
# Résultats sauvegardés automatiquement dans runs/
import json

with open('runs/units_results.json') as f:
    r = json.load(f)

print(f"Accuracy         : {r['accuracy']:.4f}")
print(f"Balanced Accuracy: {r['balanced_accuracy']:.4f}")
print(f"Macro F1         : {r['macro_f1']:.4f}")
# Out:
# Accuracy         : 0.6606
# Balanced Accuracy: 0.5203
# Macro F1         : 0.5314

# %%
# !git fetch
# !git checkout units-large-augmentation
# !python train.py --model units --epochs 150
# Out:
# M	runs/patchtst_best.pt
# Branch 'units-large-augmentation' set up to track remote branch 'units-large-augmentation' from 'origin'.
# Switched to a new branch 'units-large-augmentation'
# Device: cuda
# Loading LSST dataset...
#   Train: (2459, 36, 6)  |  Test: (2466, 36, 6)
#   Classes: ['15' '16' '42' '52' '53' '6' '62' '64' '65' '67' '88' '90' '92' '95']
#   Timesteps: 36  |  Channels: 6
# seq_len=36, n_channels=6, n_classes=14
#
# ...
# Training UniTS (NeurIPS 2024)
# ...
# UniTS — 1,605,454 trainable parameters
# Epoch 001/150 | Train loss 2.1503 acc 0.3469 | Val loss 1.9795 acc 0.4250 | Best acc 0.4250 | 2s
# Epoch 005/150 | Train loss 1.7731 acc 0.4725 | Val loss 1.6933 acc 0.5158 | Best acc 0.5158 | 9s
# Epoch 010/150 | Train loss 1.6234 acc 0.5392 | Val loss 1.6294 acc 0.5466 | Best acc 0.5466 | 17s
# Epoch 015/150 | Train loss 1.5864 acc 0.5551 | Val loss 1.5381 acc 0.5835 | Best acc 0.5835 | 26s
# ...

# %%
import json

with open('runs/units_results.json') as f:
    r = json.load(f)

print(f"Accuracy         : {r['accuracy']:.4f}")
print(f"Balanced Accuracy: {r['balanced_accuracy']:.4f}")
print(f"Macro F1         : {r['macro_f1']:.4f}")
# Out:
# Accuracy         : 0.6346
# Balanced Accuracy: 0.4892
# Macro F1         : 0.5040
